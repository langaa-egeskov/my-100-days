# %% [markdown]
# Code Challenge 13: Highest Rated Movie Directors
# - use template provided by try to implement some of the improvements suggested in discussion
# - Try to use itertools groupby and statistics.mean
# - Consider using a second named Tuple

# %% [markdown]
# First get the column names that `csv.DictReader` is going to use as dictionary keys for each row

# %%
! head -n 1 movie_metadata.csv

# %%
import csv
from collections import defaultdict, namedtuple
from itertools import groupby
import statistics

MOVIE_DATA = 'movie_metadata.csv'
NUM_TOP_DIRECTORS = 20
MIN_MOVIES = 4
MIN_YEAR = 1960

Movie = namedtuple('Movie', 'title year score')
Films = namedtuple('Films', 'director films average_score')

def get_movies_by_director(data = MOVIE_DATA):
    '''Extracts all movies from csv and stores them in a dictionary
    where keys are directors, and values is a list of movies (named tuples)'''
    movies = defaultdict(list)
    with open(data, encoding = 'utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        movies = sorted([(row['director_name'], Movie(title = row['movie_title'].strip(), year  = row['title_year'], 
                                                score = float(row['imdb_score']))) for row in reader], key = lambda k:k[0]) 
    return {director : [movie[1] for movie in g] for director, g in groupby(movies, lambda k:k[0])}

def get_top_directors_films(data):
    '''Get the films for the top directors, 
       in data k is director v is movie list'''
    films = sorted([Films(director = k, films = v, average_score = _calc_mean(v)) 
                    for k, v in data.items() if len(v) >= MIN_MOVIES], reverse=True, key = lambda k:k.average_score)
    return films[:20]


def _calc_mean(movies):
    '''Helper method to calculate mean of list of Movie namedtuples'''
    return statistics.mean([movie.score for movie in movies])


def print_results(films):
    '''Print directors ordered by highest average rating. For each director
    print his/her movies also ordered by highest rated movie.
    See http://pybit.es/codechallenge13.html for example output'''
    for film in films:
        print(f'{film.director}')
        for movie in film.films:
            print(f'\t\t{movie}')
        print(f'')
    return
    #fmt_director_entry = '{counter}. {director:<52} {avg}'
    #fmt_movie_entry = '{year}] {title:<50} {score}'
    #sep_line = '-' * 60


#def main():
    '''This is a template, feel free to structure your code differently.
    We wrote some tests based on our solution: test_directors.py'''
    directors = get_movies_by_director()
    films = get_average_scores(directors)
    print_results(directors)


#if __name__ == '__main__':
#    main()

# %%
directors = get_movies_by_director()
films = get_top_directors_films(directors)
for film in films:
        print(f'{film.director}')
        for movie in film.films:
            print(f'\tTitle: {movie.title},\tYear: {movie.year},\tScore: {movie.score}')
        print(f'')
#print_results(films)
# Out:
# Sergio Leone
# 	Title: Once Upon a Time in America,		Year: 1984,	Score: 8.4
# 	Title: Once Upon a Time in the West,		Year: 1968,	Score: 8.6
# 	Title: The Good, the Bad and the Ugly,		Year: 1966,	Score: 8.9
# 	Title: A Fistful of Dollars,		Year: 1964,	Score: 8.0
#
# Christopher Nolan
# 	Title: The Dark Knight Rises,		Year: 2012,	Score: 8.5
# 	Title: The Dark Knight,		Year: 2008,	Score: 9.0
# 	Title: Interstellar,		Year: 2014,	Score: 8.6
# 	Title: Inception,		Year: 2010,	Score: 8.8
# 	Title: Batman Begins,		Year: 2005,	Score: 8.3
# 	Title: Insomnia,		Year: 2002,	Score: 7.2
# 	Title: The Prestige,		Year: 2006,	Score: 8.5
# 	Title: Memento,		Year: 2000,	Score: 8.5
#
# Hayao Miyazaki
# 	Title: Ponyo,		Year: 2008,	Score: 7.7
# 	Title: Howl's Moving Castle,		Year: 2004,	Score: 8.2
# 	Title: Princess Mononoke,		Year: 1997,	Score: 8.4
# 	Title: Spirited Away,		Year: 2001,	Score: 8.6
#
# Quentin Tarantino
# 	Title: Django Unchained,		Year: 2012,	Score: 8.5
# 	Title: Inglourious Basterds,		Year: 2009,	Score: 8.3
# 	Title: The Hateful Eight,		Year: 2015,	Score: 7.9
# 	Title: Kill Bill: Vol. 1,		Year: 2003,	Score: 8.1
# 	Title: Kill Bill: Vol. 2,		Year: 2004,	Score: 8.0
# 	Title: Jackie Brown,		Year: 1997,	Score: 7.5
# 	Title: Pulp Fiction,		Year: 1994,	Score: 8.9
# 	Title: Reservoir Dogs,		Year: 1992,	Score: 8.4
#
# Frank Capra
# 	Title: It's a Wonderful Life,		Year: 1946,	Score: 8.6
# 	Title: Pocketful of Miracles,		Year: 1961,	Score: 7.3
# 	Title: You Can't Take It with You,		Year: 1938,	Score: 8.0
# 	Title: Mr. Smith Goes to Washington,		Year: 1939,	Score: 8.2
# 	Title: It Happened One Night,		Year: 1934,	Score: 8.2
#
# David Lean
# 	Title: A Passage to India,		Year: 1984,	Score: 7.4
# 	Title: Lawrence of Arabia,		Year: 1962,	Score: 8.4
# 	Title: Doctor Zhivago,		Year: 1965,	Score: 8.0
# 	Title: The Bridge on the River Kwai,		Year: 1957,	Score: 8.2
#
# Stanley Kubrick
# 	Title: Eyes Wide Shut,		Year: 1999,	Score: 7.3
# 	Title: Lolita,		Year: 1962,	Score: 7.7
# 	Title: The Shining,		Year: 1980,	Score: 8.4
# 	Title: Barry Lyndon,		Year: 1975,	Score: 8.1
# 	Title: 2001: A Space Odyssey,		Year: 1968,	Score: 8.3
# 	Title: Lolita,		Year: 1962,	Score: 7.7
# 	Title: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb,		Year: 1964,	Score: 8.5
#
# Billy Wilder
# 	Title: The Front Page,		Year: 1974,	Score: 7.3
# 	Title: The Apartment,		Year: 1960,	Score: 8.3
# 	Title: Some Like It Hot,		Year: 1959,	Score: 8.3
# 	Title: The Lost Weekend,		Year: 1945,	Score: 8.0
#
# Frank Darabont
# 	Title: The Majestic,		Year: 2001,	Score: 6.9
# 	Title: The Green Mile,		Year: 1999,	Score: 8.5
# 	Title: The Shawshank Redemption,		Year: 1994,	Score: 9.3
# 	Title: The Mist,		Year: 2007,	Score: 7.2
#
# Joss Whedon
# 	Title: Avengers: Age of Ultron,		Year: 2015,	Score: 7.5
# 	Title: The Avengers,		Year: 2012,	Score: 8.1
# 	Title: The Avengers,		Year: 2012,	Score: 8.1
# 	Title: Serenity,		Year: 2005,	Score: 8.0
#
# James Cameron
# 	Title: Avatar,		Year: 2009,	Score: 7.9
# 	Title: Titanic,		Year: 1997,	Score: 7.7
# 	Title: Terminator 2: Judgment Day,		Year: 1991,	Score: 8.5
# 	Title: True Lies,		Year: 1994,	Score: 7.2
# 	Title: The Abyss,		Year: 1989,	Score: 7.6
# 	Title: Aliens,		Year: 1986,	Score: 8.4
# 	Title: The Terminator,		Year: 1984,	Score: 8.1
#
# Alfonso Cuarón
# 	Title: Harry Potter and the Prisoner of Azkaban,		Year: 2004,	Score: 7.8
# 	Title: Gravity,		Year: 2013,	Score: 7.8
# 	Title: Children of Men,		Year: 2006,	Score: 7.9
# 	Title: Y Tu Mamá También,		Year: 2001,	Score: 7.7
#
# Richard Brooks
# 	Title: In Cold Blood,		Year: 1967,	Score: 8.0
# 	Title: Cat on a Hot Tin Roof,		Year: 1958,	Score: 8.1
# 	Title: Elmer Gantry,		Year: 1960,	Score: 7.9
# 	Title: Deadline - U.S.A.,		Year: 1952,	Score: 7.2
#
# Alejandro G. Iñárritu
# 	Title: The Revenant,		Year: 2015,	Score: 8.1
# 	Title: Biutiful,		Year: 2010,	Score: 7.5
# 	Title: Babel,		Year: 2006,	Score: 7.5
# 	Title: 21 Grams,		Year: 2003,	Score: 7.7
# 	Title: Birdman or (The Unexpected Virtue of Ignorance),		Year: 2014,	Score: 7.8
# 	Title: Amores Perros,		Year: 2000,	Score: 8.1
#
# Fred Zinnemann
# 	Title: Julia,		Year: 1977,	Score: 7.4
# 	Title: A Man for All Seasons,		Year: 1966,	Score: 7.9
# 	Title: The Nun's Story,		Year: 1959,	Score: 7.6
# 	Title: From Here to Eternity,		Year: 1953,	Score: 7.8
# 	Title: High Noon,		Year: 1952,	Score: 8.1
#
# David Fincher
# 	Title: The Curious Case of Benjamin Button,		Year: 2008,	Score: 7.8
# 	Title: The Girl with the Dragon Tattoo,		Year: 2011,	Score: 7.8
# 	Title: Zodiac,		Year: 2007,	Score: 7.7
# 	Title: Fight Club,		Year: 1999,	Score: 8.8
# 	Title: Gone Girl,		Year: 2014,	Score: 8.1
# 	Title: Alien 3,		Year: 1992,	Score: 6.4
# 	Title: The Game,		Year: 1997,	Score: 7.8
# 	Title: Panic Room,		Year: 2002,	Score: 6.8
# 	Title: The Social Network,		Year: 2010,	Score: 7.7
# 	Title: Se7en,		Year: 1995,	Score: 8.6
#
# Peter Weir
# 	Title: Master and Commander: The Far Side of the World,		Year: 2003,	Score: 7.4
# 	Title: The Truman Show,		Year: 1998,	Score: 8.1
# 	Title: Dead Poets Society,		Year: 1989,	Score: 8.0
# 	Title: Witness,		Year: 1985,	Score: 7.4
#
# Peter Jackson
# 	Title: The Hobbit: The Battle of the Five Armies,		Year: 2014,	Score: 7.5
# 	Title: The Hobbit: The Desolation of Smaug,		Year: 2013,	Score: 7.9
# 	Title: King Kong,		Year: 2005,	Score: 7.2
# 	Title: The Hobbit: An Unexpected Journey,		Year: 2012,	Score: 7.9
# 	Title: The Lord of the Rings: The Fellowship of the Ring,		Year: 2001,	Score: 8.8
# 	Title: The Lovely Bones,		Year: 2009,	Score: 6.7
# 	Title: The Lord of the Rings: The Return of the King,		Year: 2003,	Score: 8.9
# 	Title: The Lord of the Rings: The Two Towers,		Year: 2002,	Score: 8.7
# 	Title: King Kong,		Year: 2005,	Score: 7.2
# 	Title: Heavenly Creatures,		Year: 1994,	Score: 7.4
# 	Title: The Lovely Bones,		Year: 2009,	Score: 6.7
# 	Title: King Kong,		Year: 2005,	Score: 7.2
#
# Martin Scorsese
# 	Title: Hugo,		Year: 2011,	Score: 7.5
# 	Title: The Aviator,		Year: 2004,	Score: 7.5
# 	Title: The Wolf of Wall Street,		Year: 2013,	Score: 8.2
# 	Title: Gangs of New York,		Year: 2002,	Score: 7.5
# 	Title: The Departed,		Year: 2006,	Score: 8.5
# 	Title: Shutter Island,		Year: 2010,	Score: 8.1
# 	Title: Casino,		Year: 1995,	Score: 8.2
# 	Title: Mean Streets,		Year: 1973,	Score: 7.4
# 	Title: Cape Fear,		Year: 1991,	Score: 7.3
# 	Title: The Age of Innocence,		Year: 1993,	Score: 7.2
# 	Title: Bringing Out the Dead,		Year: 1999,	Score: 6.8
# 	Title: Kundun,		Year: 1997,	Score: 7.0
# 	Title: Goodfellas,		Year: 1990,	Score: 8.7
# 	Title: Raging Bull,		Year: 1980,	Score: 8.3
# 	Title: New York, New York,		Year: 1977,	Score: 6.7
# 	Title: The Color of Money,		Year: 1986,	Score: 7.0
# 	Title: The Last Temptation of Christ,		Year: 1988,	Score: 7.6
# 	Title: Taxi Driver,		Year: 1976,	Score: 8.3
# 	Title: Shine a Light,		Year: 2008,	Score: 7.2
# 	Title: The Last Waltz,		Year: 1978,	Score: 8.2
#
# Matthew Vaughn
# 	Title: X-Men: First Class,		Year: 2011,	Score: 7.8
# 	Title: Stardust,		Year: 2007,	Score: 7.7
# 	Title: Kick-Ass,		Year: 2010,	Score: 7.7
# 	Title: Layer Cake,		Year: 2004,	Score: 7.4

# %% [markdown]
# TODO
# - This works in a notebook.  For Day 7 or 6 b whatever I decide to call it lets get it to work in a separate file using the .main stuff
# - And also for day 7 lets try to figure out the print results fx in the template
# - Also rewrite the tests to work with my functions
# - try to fix the printing

# %%
import pytest
import ipytest

# enable IPython magics for test execution
import ipytest.magics

# enable pytest's assertions
ipytest.config.rewrite_asserts = True

# set the filename
__file__ = 'Day_006.ipynb'

# %%
# from directors import get_movies_by_director, get_average_scores, _calc_mean


def test():
    directors = get_movies_by_director()

    assert 'Sergio Leone' in directors
    assert 'Andrew Stanton' in directors  # has 3 movies, but not yet filtered
    assert len(directors['Sergio Leone']) == 4
    assert len(directors['Peter Jackson']) == 12

    movies_sergio = directors['Sergio Leone']
    movies_nolan = directors['Christopher Nolan']
    assert _calc_mean(movies_sergio) == 8.5
    assert _calc_mean(movies_nolan) == 8.4

    directors = get_average_scores(directors)
    assert 'Andrew Stanton' not in directors  # director 3 movies now filtered out

    expected_directors = ['Sergio Leone', 'Christopher Nolan', 'Quentin Tarantino',
                          'Hayao Miyazaki', 'Frank Darabont', 'Stanley Kubrick']
    expected_avg_scores = [8.5, 8.4, 8.2, 8.2, 8.0, 8.0]
    expected_num_movies = [4, 8, 8, 4, 4, 7]
    report = sorted(directors.items(), key=lambda x: float(x[0][1]), reverse=True)
    for counter, (i, j, k) in enumerate(
                            zip(expected_directors,
                                expected_avg_scores, expected_num_movies)):
        assert report[counter][0] == (i, j)
        assert len(report[counter][1]) == k
        assert  _calc_mean(report[counter][1]) == j

    return "tests pass"

    
ipytest.run()
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.7.0, pytest-3.8.2, py-1.7.0, pluggy-0.7.1
# rootdir: /Users/NewEarth/Documents/Projects/ANewTraining/Python/HundredDaysCode/My100Days, inifile:
# collected 1 item
#
# Day_006.py F                                                             [100%]
#
# =================================== FAILURES ===================================
# _____________________________________ test _____________________________________
#
#     def test():
#         directors = get_movies_by_director()
#
#         assert 'Sergio Leone' in directors
#         assert 'Andrew Stanton' in directors  # has 3 movies, but not yet filtered
#         assert len(directors['Sergio Leone']) == 4
#         assert len(directors['Peter Jackson']) == 12
#
#         movies_sergio = directors['Sergio Leone']
#         movies_nolan = directors['Christopher Nolan']
# >       assert _calc_mean(movies_sergio) == 8.5
# E       AssertionError: assert 8.475 == 8.5
# E        +  where 8.475 = _calc_mean([Movie(title='Once Upon a Time in America', year='1984', score=8.4), Movie(title='Once Upon a Time in the West', year=...'The Good, the Bad and the Ugly', year='1966', score=8.9), Movie(title='A Fistful of Dollars', year='1964', score=8.0)])
#
# <ipython-input-10-c943c3f72ac7>:14: AssertionError
# =========================== 1 failed in 0.24 seconds ===========================
